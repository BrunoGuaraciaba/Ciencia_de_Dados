# %% [markdown]
# ![cabecalho_notebook.png](attachment:cabecalho_notebook.png)

# %% [markdown]
# Módulo 21 <br> Professor: Lucas Serra

# %% [markdown]
# # Módulo 21 - Atividade 3

# %% [markdown]
# ![dvd-rental-sample-database-diagram.png](attachment:dvd-rental-sample-database-diagram.png)

# %% [markdown]
# ### Calcule a média por nome e sobrenome do ator da seguintes variáveis:
# - rental_duration
# - rental_rate
# - length
# - replacement_cost
#
# ![image.png](attachment:6be90db4-8345-459c-b3ed-0c84a5d4682d.png)

# %% [raw]
# #QUERY
# SELECT
# 	a.first_name,
# 	a.last_name,
# 	AVG(f.rental_duration) AS avg_rental_duration,
# 	AVG(f.rental_rate) AS avg_rental_rate,
# 	AVG(f.length) AS avg_length,
# 	AVG(f.replacement_cost) AS avg_replacement_cost
# FROM actor a
# JOIN film_actor fa
# 	ON a.actor_id = fa.actor_id
# JOIN film f
# 	ON fa.film_id = f.film_id
# GROUP BY
# 	a.first_name,
# 	a.last_name
# ORDER BY
# 	a.last_name,
# 	a.first_name;

# %% [markdown]
# ### Calcule a soma de amount (preço total do aluguel) por nome, sobrenome e email do cliente (customer) e indique os 10 clientes que mais gastaram e os 10 que menos gastaram.

# %% [markdown]
# ## Mais gastaram
# ![image.png](attachment:21dc2e9d-d038-4369-b12a-e2b03d940d12.png)

# %%
##

# %% [markdown]
# ## Menos gastaram
# ![image.png](attachment:ec96466e-fe65-4617-b0a3-f5e7da7ccb45.png)
